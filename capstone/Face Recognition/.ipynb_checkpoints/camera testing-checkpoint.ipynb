# %%
from face_module.database import *
from face_module.proc import *

from camera import take_picture
import matplotlib.pyplot as plt

from facenet_models import FacenetModel

# %matplotlib notebook

# %%
# open app
# welcome user
# ask to take a photo
# take a photo
# dat.predict 
# --> if unknown, prompt user to add 2 photos to the database
# --> If known, welcome user

# %%
def photo_scan() :
    
    model = FacenetModel()
    img_array = take_picture()
    fig,ax = plt.subplots()
    ax.imshow(img_array)
    
    people = get_people()
    dat = database(people)
    
    boxes, probabilities, landmarks = model.detect(img_array)
    
    
    print('modeled')
    for index, box in enumerate(boxes) :
        descriptions = model.compute_descriptors(img_array, [box])
        
    for descrp in descriptions :
        if (dat.predict(descrp) == "Unknown") :
            create = input("User was not found. Would you like to create a new user? (y/n)")
            if (create == "y") :
                create_user("caden")

# %%
def get_people() :
    people = []
    for subdir, dirs, files in os.walk("./data/"):
        for f in files :
            if f.endswith(".npy") :
                people.append(f[:-4])
        
    return people

# %%
get_people()
# Out:
# ['robert', 'scarlet', 'tom']

# %%
def create_user(Person) :

    filepaths = []
    filelist = ""

    person_path = "./data/" + Person
    
    os.mkdir(person_path)
    
    vectorized_images = []
    
    for i in range (3) :
        vectorized_images.append(take_picture())
        print("photo taken!")
        
    save_path = "./data/" + Person + ".npy"

    np.save(save_path, vectorized_images)

# %%
start = input("Welcome! Would you like to open iHealthBuddy? (y/n)\n\n")

if (start == "y") :
    photo_scan()
else : 
    print("See you next time!")
# Out:
# Welcome! Would you like to open iHealthBuddy? (y/n)
#
# y
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [25], in <cell line: 3>()
#       1 start = input("Welcome! Would you like to open iHealthBuddy? (y/n)\n\n")
#       3 if (start == "y") :
# ----> 4     photo_scan()
#       5 else :
#       6     print("See you next time!")
#
# Input In [23], in photo_scan()
#       6 ax.imshow(img_array)
#       8 people = get_people()
# ----> 9 dat = database(people)
#      11 boxes, probabilities, landmarks = model.detect(img_array)
#      14 print('modeled')
#
# File c:\users\caden\programming\bwsi\ryan-sus\capstone\face recognition\face_module\face_module\database.py:72, in database(names)
#      70 for name in names :
#      71   name_path = "./data/" + name + ".npy"
# ---> 72   vectorized_images = np.load(name_path, allow_pickle=True)
#      74   descriptions = []
#      76   for image in vectorized_images :
#      77     # assumes ``pic`` is a numpy array of shape (R, C, 3) (RGB is the last dimension)
#
# File C:\anaconda3\envs\capstone\lib\site-packages\numpy\lib\npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/caden.npy'
